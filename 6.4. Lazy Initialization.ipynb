# %%
import torch
from torch import nn

# %%
net = nn.Sequential(
    nn.LazyLinear(256),
    nn.ReLU(),
    nn.LazyLinear(10)
)
# Out:
# C:\ProgramData\miniconda3\envs\d2l\lib\site-packages\torch\nn\modules\lazy.py:180: UserWarning: Lazy modules are a new feature under heavy development so changes to the API or functionality can happen at any moment.
#   warnings.warn('Lazy modules are a new feature under heavy development '

# %%
net
# Out:
# Sequential(
#   (0): LazyLinear(in_features=0, out_features=256, bias=True)
#   (1): ReLU()
#   (2): LazyLinear(in_features=0, out_features=10, bias=True)
# )

# %%
net[0].weight

# %%
X = torch.rand(2, 20)
net(X)
# Out:
# tensor([[ 0.2527,  0.3479, -0.0490,  0.1046, -0.0719,  0.2481, -0.4343,  0.1434,
#           0.0676, -0.2633],
#         [ 0.1930,  0.3064, -0.0151,  0.0303, -0.1093,  0.2202, -0.1577,  0.0654,
#           0.0198, -0.2602]], grad_fn=<AddmmBackward0>)

# %%
net[0].weight
# Out:
# Parameter containing:
# tensor([[-0.2081,  0.1194,  0.0628,  ...,  0.2054, -0.2024, -0.0551],
#         [-0.1505,  0.0212,  0.2108,  ..., -0.1170, -0.0616, -0.0511],
#         [-0.1142, -0.0943, -0.1955,  ...,  0.0737,  0.1427,  0.0012],
#         ...,
#         [-0.1064, -0.0767,  0.0780,  ..., -0.0492, -0.0415, -0.1866],
#         [ 0.1555, -0.2101,  0.2151,  ...,  0.2234, -0.0665,  0.1369],
#         [ 0.0907, -0.1317, -0.1003,  ...,  0.1288, -0.0481,  0.0828]],
#        requires_grad=True)
