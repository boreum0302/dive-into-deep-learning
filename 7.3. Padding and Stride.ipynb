# %%
import torch
from torch import nn

# %%
conv2d = nn.Conv2d(in_channels=1, out_channels=1, kernel_size=(5, 3), padding=(2, 1))

# %%
X = torch.rand((8, 8))

# %%
X = X.reshape(1, 1, *X.shape)  # (batch_size, channel, height, width)

# %%
conv2d(X).shape
# Out:
# torch.Size([1, 1, 8, 8])

# %%
conv2d = nn.Conv2d(in_channels=1, out_channels=1, kernel_size=3, padding=1, stride=2)
conv2d(X).shape
# Out:
# torch.Size([1, 1, 4, 4])

# %%
conv2d = nn.Conv2d(in_channels=1, out_channels=1, kernel_size=(3, 5), padding=(0, 1), stride=(3, 5))
conv2d(X).shape
# Out:
# torch.Size([1, 1, 2, 2])
